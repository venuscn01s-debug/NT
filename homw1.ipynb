# %%
m=int(input())
print(f'{2*m}')
# Out:
# 2

# %%
a,b=map(int,input().split())
if b>a:
    print("error")
else:
    print(f'{a*b-(b/2)**2*3.14:.2f}')
# Out:
# 1.21

# %%
a=input()
b=ord(a)
if 123>b>96:
    print(f"{chr(b-32)}")
elif 91>b>64:
    print(f'{chr(b+32)}')
else:
    print('error')
# Out:
# S

# %%
a=input()
b=int(ord(a))
if 123>b>96:
    print("chữ cái âpbet")
elif 91>b>64:
    print('chữ cái anphabet')
else:
    print('không phải ck apb')
# Out:
# không phải ck apb

# %%
a=input()
b=int(ord(a))
if b==65:
    print('không có chữ cái liền trước')
elif 91>b>65:
    print(f'{chr(b+32-1)}')
else:
    print("kp ck in hoa")
# Out:
# d

# %%
import math
a,b,c=map(int,input().split())
d=(a+b+c)/2
if a+b>c and a+c>b and c+b>a:
    print(f'là tg với S={math.sqrt(d*(d-a)*(d-b)*(d-c))}')
# Out:
# là tg với S=6.0

# %%
s = input()
print(s[4], s[8])
# Out:
# e j

# %%
a,b,c=input().split()
d=int(c)-int(b)
gia={1:1984,2:2050,3:2380,4:2998,5:3350,6:3460}
if d>0:
    if 51>d>0:
        print(f'{a}:{d*gia[1]*1.08:.0f}')
    elif 101>d>=51:
        print(f'{a}:{((d-50)*gia[2]+50*gia[1])*1.08:.0f}')
    elif 201>d>=101:
        print(f'{a}:{((d-100)*gia[3]+50*(gia[2]+gia[1]))*1.08:.0f}')
    elif 301>d>=201:
        print(f'{a}:{((d-200)*gia[4]+50*(gia[1]+gia[2]+2*gia[3]))*1.08:.0f}')
    elif 401>d>=301:
        print(f'{a}:{((d-300)*gia[5]+50*(gia[1]+gia[2]+2*gia[3]+2*gia[4]))*1.08:.0f}')
    elif d>=401:
        print(f'{a}:{((d-400)*gia[6]+50*(gia[1]+gia[2]+2*gia[3]+2*gia[4]+2*gia[5]))*1.08:.0f}')
else:
    print('chịu')
# Out:
# ot:107136

# %%
a=int(input())
if a%2==0:
    print("chan")
else :
    print("le")
# Out:
# le

# %%
a=int(input())
if a%5==0 and a%2!=0:
    print("true")
else:
    print("false")
# Out:
# true

# %%
a=int(input())
if a%3==0 and a%5==0:
     print("true")
else:
    print("false")
# Out:
# true

# %%
a=int(input())
b=2026
if b-a>=18:
    print(f"{b-a}")
else:
    print('next')

# %%
a,b=map(int,input().split())
if a>b:
    print(a)
elif a<b:
    print(b)
else:
    print('a=b')
# Out:
# a=b

# %%
a=input()
b=ord(a)
if 57>=b>=48:
    print('số')
elif 122>=b>=97 or 90>=b>=75:
    print('chữ')
else:
    print('chịu')
# Out:
# chữ

# %%
a=int(input())
hl=['yeu','tb','kha','gioi']
hocluc=sum(a>=m for m in [5,6.5,8])
print(hl[hocluc])
# Out:
# gioi

# %%
a=int(input())
if a%400==0 or a%4==0 and a%100!=0:
    print('năm nhuận')
else:
    print('năm kh nhuận')
# Out:
# năm nhuận

# %%
n=int(input())
doc=("không","một","hai","ba","bốn","năm","sáu","bảy","tám","chín")
if 0<=n<=9:
    print(f"đây là số : {doc[n]}")
else :
    print("không đọc ")

# %%
a=int(input())
if a<=4:
    print('tạch')
else:
    print('pass')
# Out:
# pass
